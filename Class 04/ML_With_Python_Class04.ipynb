# %% [markdown]
# # **Class 04**

# %% [markdown]
# **Feature Engineering & Normalization**

# %%
import pandas as pd

# %%
dataset=pd.read_csv('/content/mobile_dataset.csv')

# %%
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
dataset.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
dataset.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# # Applying Normalization in this Dataset

# %% [markdown]
# ## **Applying Min-Max Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn=MinMaxScaler()

# %%
mn.fit_transform(dataset)
# Out:
# array([[0.22778891, 0.        , 0.68      , ..., 0.        , 1.        ,
#         0.33333333],
#        [0.34736139, 1.        , 0.        , ..., 1.        , 0.        ,
#         0.66666667],
#        [0.04141617, 1.        , 0.        , ..., 1.        , 0.        ,
#         0.66666667],
#        ...,
#        [0.94188377, 0.        , 0.16      , ..., 1.        , 0.        ,
#         1.        ],
#        [0.6753507 , 0.        , 0.16      , ..., 1.        , 1.        ,
#         0.        ],
#        [0.00601202, 1.        , 0.6       , ..., 1.        , 1.        ,
#         1.        ]])

# %%
pd.DataFrame(mn.fit_transform(dataset))
# Out:
#             0    1     2    3         4    5         6         7         8   \
# 0     0.227789  0.0  0.68  0.0  0.052632  0.0  0.080645  0.555556  0.900000
# 1     0.347361  1.0  0.00  1.0  0.000000  1.0  0.822581  0.666667  0.466667
# 2     0.041416  1.0  0.00  1.0  0.105263  1.0  0.629032  0.888889  0.541667
# 3     0.076152  1.0  0.80  0.0  0.000000  0.0  0.129032  0.777778  0.425000
# 4     0.881764  1.0  0.28  0.0  0.684211  1.0  0.677419  0.555556  0.508333
# ...        ...  ...   ...  ...       ...  ...       ...       ...       ...
# 1995  0.195725  1.0  0.00  1.0  0.000000  1.0  0.000000  0.777778  0.216667
# 1996  0.977956  1.0  0.84  1.0  0.000000  0.0  0.596774  0.111111  0.891667
# 1997  0.941884  0.0  0.16  1.0  0.052632  1.0  0.548387  0.666667  0.233333
# 1998  0.675351  0.0  0.16  0.0  0.210526  1.0  0.709677  0.000000  0.541667
# 1999  0.006012  1.0  0.60  1.0  0.263158  1.0  0.693548  0.888889  0.733333
#
# ...

# %% [markdown]
# ## **Standard Scaler**

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()

# %%
sd.fit_transform(dataset)
# Out:
# array([[-0.90259726, -0.9900495 ,  0.83077942, ..., -1.00601811,
#          0.98609664, -0.4472136 ],
#        [-0.49513857,  1.0100505 , -1.2530642 , ...,  0.99401789,
#         -1.01409939,  0.4472136 ],
#        [-1.5376865 ,  1.0100505 , -1.2530642 , ...,  0.99401789,
#         -1.01409939,  0.4472136 ],
#        ...,
#        [ 1.53077336, -0.9900495 , -0.76274805, ...,  0.99401789,
#         -1.01409939,  1.34164079],
#        [ 0.62252745, -0.9900495 , -0.76274805, ...,  0.99401789,
#          0.98609664, -1.34164079],
#        [-1.65833069,  1.0100505 ,  0.58562134, ...,  0.99401789,
#          0.98609664,  1.34164079]])

# %%
pd.DataFrame(sd.fit_transform(dataset))
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.902597 -0.990050  0.830779 -1.019184 -0.762495 -1.043966 -1.380644
# 1    -0.495139  1.010051 -1.253064  0.981177 -0.992890  0.957886  1.155024
# 2    -1.537686  1.010051 -1.253064  0.981177 -0.532099  0.957886  0.493546
# 3    -1.419319  1.010051  1.198517 -1.019184 -0.992890 -1.043966 -1.215274
# 4     1.325906  1.010051 -0.395011 -1.019184  2.002254  0.957886  0.658915
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995 -1.011860  1.010051 -1.253064  0.981177 -0.992890  0.957886 -1.656260
# 1996  1.653694  1.010051  1.321096  0.981177 -0.992890 -1.043966  0.383299
# 1997  1.530773 -0.990050 -0.762748  0.981177 -0.762495  0.957886  0.217930
# 1998  0.622527 -0.990050 -0.762748 -1.019184 -0.071307  0.957886  0.769162
# 1999 -1.658331  1.010051  0.585621  0.981177  0.159088  0.957886  0.714039
#
# ...

# %% [markdown]
# ## **Feature Engineering**

# %%
dataset.iloc[:,:1]
# Out:
#       battery_power
# 0               842
# 1              1021
# 2               563
# 3               615
# 4              1821
# ...             ...
# 1995            794
# 1996           1965
# 1997           1911
# 1998           1512
# 1999            510
#
# [2000 rows x 1 columns]

# %%
dataset.iloc[:,:-1]
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
x= dataset.iloc[:,:-1]

# %% [markdown]
# Dependent Column more than 1 hole ei iloc use korbo

# %%
y= dataset.iloc[:,-1]
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
y=dataset["price_range"]
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest,chi2

# %% [markdown]
# 21 ta feature er moddhe kon feature ta select korbe eita ashbe chi2 er reult er upor . Eita score_function e store hobe erpr best feature select korbe SelectKBest er maddhome

# %%
sc= SelectKBest(score_func=chi2)

# %%
sc.fit(x,y)
# Out:
# SelectKBest(score_func=<function chi2 at 0x7eae78422020>)

# %%
sc.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %% [markdown]
# 1. Tar mane 20 ta independent column er score eikhane dekha jaitese
# 2. Mane eikhane  13 number column sobcheye beshi important

# %%
pd.DataFrame(sc.scores_)
# Out:
#                 0
# 0    14129.866576
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 4       10.135166
# 5        1.521572
# 6       89.839124
# 7        0.745820
# 8       95.972863
# 9        9.097556
# 10       9.186054
# 11   17363.569536
# 12    9810.586750
# 13  931267.519053
# 14       9.614878
# 15      16.480319
# 16      13.236400
# 17       0.327643
# 18       1.928429
# 19       0.422091

# %%
pd.concat([pd.DataFrame(x.columns),pd.DataFrame(sc.scores_)],axis=1)
# Out:
#                 0              0
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
pc= pd.concat([pd.DataFrame(x.columns),pd.DataFrame(sc.scores_,columns=["Score"])],axis=1)

# %%
pc.nlargest(8,"Score")
# Out:
#                 0          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
