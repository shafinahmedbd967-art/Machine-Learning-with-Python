# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/content/data.csv')

# %%
dataset
# Out:
#                Timestamp     What is your name?  What is your age?  \
# 0    12/24/2022 15:02:36  Ayesha Siraji Shejuty                 21
# 1    12/24/2022 15:08:21        Nushrah Ipshita                 18
# 2    12/24/2022 15:09:34      Nabhan Ezaz Ilhan                 18
# 3    12/24/2022 17:38:50   Rashedul Hoque Robin                 23
# 4    12/24/2022 17:50:51        Mubashira Hoque                 22
# ..                   ...                    ...                ...
# 406    1/1/2023 22:10:57            Nila rahman                 19
# 407    1/1/2023 22:11:29          Abayat Rahman                 21
# 408    1/1/2023 22:12:13            Talha Ahmed                 23
# 409    1/1/2023 22:12:49         Latifur Rahman                 21
# 410    1/1/2023 22:13:25              Dr.Biplob                 29
#
#     What is your gender? A child should sleep?  \
# 0                 Female            8 to 9 hrs
# 1                 Female            8 to 9 hrs
# 2                   Male            8 to 9 hrs
# 3                   Male            8 to 9 hrs
# 4                 Female           9 to 10 hrs
# ..                   ...                   ...
# 406               Female            8 to 9 hrs
# 407                 Male            8 to 9 hrs
# 408                 Male            8 to 9 hrs
# 409                 Male            8 to 9 hrs
# 410                 Male            8 to 9 hrs
#
#     At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                          3 to 6 year
# 1                                          3 to 6 year
# 2                                          3 to 6 year
# 3                                          3 to 6 year
# 4                                          3 to 6 year
# ..                                                 ...
# 406                                        3 to 6 year
# 407                                        1 to 3 year
# 408                                        1 to 3 year
# 409                                        1 to 3 year
# 410                                        3 to 6 year
#
#     During the early growing stage of a child the cause of malnutrition according to you is-  \
# 0                                              Poverty
# 1                                              Poverty
# 2                           Lack of parental awareness
# 3                           Lack of parental awareness
# 4                                              Poverty
# ..                                                 ...
# 406                                            Poverty
# 407                                            Poverty
# 408                         Lack of parental awareness
# 409                         Lack of parental awareness
# 410                         Lack of parental awareness
#
#     Child nutrition can also effect by  \
# 0              Quantity of intake food
# 1                          Environment
# 2                          Family care
# 3                          Environment
# 4                          Family care
# ..                                 ...
# 406                Physical well-being
# 407                        Family care
# 408                        Environment
# 409                        Environment
# 410                        Environment
#
#     During puberty most of the child need to take proper amount of nutrients because  \
# 0                         They have started to growing
# 1                         They have started to growing
# 2            The growth rate is massive in this period
# 3                         They have started to growing
# 4                         They have started to growing
# ..                                                 ...
# 406                       They have started to growing
# 407                       They have started to growing
# 408                       They have started to growing
# 409                       They have started to growing
# 410                       They have started to growing
#
#     The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be  \
# 0                                         Malnutrition
# 1                                         Malnutrition
# 2    No if proper nutrients is getting by other foo...
# 3    No if proper nutrients is getting by other foo...
# 4                                         Malnutrition
# ..                                                 ...
# 406                                       Malnutrition
# 407  No if proper nutrients is getting by other foo...
# 408                                       Malnutrition
# 409  No if proper nutrients is getting by other foo...
# 410                                       Malnutrition
#
#     A girl child needs to have best care during puberty  \
# 0                             Due to her mental health
# 1                             Due to her mental health
# 2                      Attractions towards uncertainty
# 3                             Due to her mental health
# 4                                 Physiological change
# ..                                                 ...
# 406                           Due to her mental health
# 407                    Attractions towards uncertainty
# 408                           Due to her mental health
# 409                    Attractions towards uncertainty
# 410                    Attractions towards uncertainty
#
#     The most common malnutrition of children in our country  \
# 0                                              Rickets
# 1                                             Marasmus
# 2                                             Marasmus
# 3                                              Rickets
# 4                                              Rickets
# ..                                                 ...
# 406                                            Rickets
# 407                                            Rickets
# 408                                            Rickets
# 409                                        Kwashiorkor
# 410                                            Rickets
#
#     Do you prefer parental awareness in case of a sound health of a child  \
# 0                                       Strongly agree
# 1                                       Strongly agree
# 2                                       Strongly agree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 406                                     Strongly agree
# 407                                     Strongly agree
# 408                                     Strongly agree
# 409                                     Strongly agree
# 410                                     Strongly agree
#
#     Nutrition of a child related to  \
# 0             Quantity of nutrients
# 1             Quantity of nutrients
# 2      Including vegetables, fruits
# 3      Including vegetables, fruits
# 4             Quantity of nutrients
# ..                              ...
# 406           Quantity of nutrients
# 407           Quantity of nutrients
# 408           Quantity of nutrients
# 409            Milk as a supplement
# 410    Including vegetables, fruits
#
#     Diarrhea is a very common disease of infant. According to you it happens due to  \
# 0    Lack of cleanliness to the instruments that ar...
# 1                                Unhealthy environment
# 2    Lack of cleanliness to the instruments that ar...
# 3                                Unhealthy environment
# 4    Lack of cleanliness to the instruments that ar...
# ..                                                 ...
# 406                              Unhealthy environment
# 407  Lack of cleanliness to the instruments that ar...
# 408  Lack of cleanliness to the instruments that ar...
# 409  Lack of cleanliness to the instruments that ar...
# 410  Lack of cleanliness to the instruments that ar...
#
#     Some people think that feeding a child more and more Can increase their body growth. But according to you it is a  \
# 0                                Cause of malnutrition
# 1                                Cause of malnutrition
# 2                                Cause of malnutrition
# 3                                           Overweight
# 4                                           Overweight
# ..                                                 ...
# 406                              Cause of malnutrition
# 407                                         Overweight
# 408                              Cause of malnutrition
# 409                              Cause of malnutrition
# 410                              Cause of malnutrition
#
#     Whole grain foods such as breads, cereals that are high in Fibre  \
# 0                                         Making stool
# 1                                         Making stool
# 2                                         Making stool
# 3                                    Helps bone growth
# 4                                         Making stool
# ..                                                 ...
# 406                                  Helps bone growth
# 407                                  Helps bone growth
# 408                                       Making stool
# 409                                       Making stool
# 410                                  Helps bone growth
#
#     Toddlers & preschoolers should have following nutrients in their diet
# 0    Milk for the growth but sometimes it causes mi...
# 1    Milk for the growth but sometimes it causes mi...
# 2    Milk for the growth but sometimes it causes mi...
# 3                              Calcium for bone growth
# 4                              Calcium for bone growth
# ..                                                 ...
# 406                            Calcium for bone growth
# 407                            Calcium for bone growth
# 408                            Calcium for bone growth
# 409                            Calcium for bone growth
# 410                            Calcium for bone growth
#
# [411 rows x 18 columns]

# %% [markdown]
# **To check Null Value**

# %%
dataset.isnull().sum()
# Out:
# Timestamp                                                                                                                                             0
# What is your name?                                                                                                                                    0
# What is your age?                                                                                                                                     0
# What is your gender?                                                                                                                                  0
# A child should sleep?                                                                                                                                 0
# At what ages do food allergies, iron deficiency and occur in children?                                                                                0
# During the early growing stage of a child the cause of malnutrition according to you is-                                                              0
# Child nutrition can also effect by                                                                                                                    0
# During puberty most of the child need to take proper amount of nutrients because                                                                      0
# The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be    0
# A girl child needs to have best care during puberty                                                                                                   0
# The most common malnutrition of children in our country                                                                                               0
# Do you prefer parental awareness in case of a sound health of a child                                                                                 0
# Nutrition of a child related to                                                                                                                       0
# Diarrhea is a very common disease of infant. According to you it happens due to                                                                       0
# Some people think that feeding a child more and more Can increase their body growth. But according to you it is a                                     0
# Whole grain foods such as breads, cereals that are high in Fibre                                                                                      0
# Toddlers & preschoolers should have following nutrients in their diet                                                                                 0
# dtype: int64

# %% [markdown]
# **Male koyta ar Female koyta ta bole dibe**

# %%
dataset["What is your gender?"].value_counts()
# Out:
# What is your gender?
# Male      207
# Female    204
# Name: count, dtype: int64

# %%
dataset["What is your gender?"].hist()
# Out:
# <Axes: >

# %%
# dataset.drop("Timestamp")  # eikhane timestamp ke row onujai khuja hoy.Tohn axix er man 0 thake .but eita ase column onujai. tai axix=1 hbe. but tateo hbe na. implace true lagbe
dataset.drop("Timestamp", axis=1, inplace=True)

# %% [markdown]
# **inplace=True** মানে হলো — পরিবর্তনটা **সরাসরি original dataframe এ** করে ফেলো, আলাদা কোনো copy বানিয়ো না।
#
# উদাহরণ দিয়ে বুঝি —
#
# **inplace=True দিলে:**
# ```python
# dataset.drop("Timestamp", axis=1, inplace=True)
# ```
# এখানে dataset এর ভেতরেই Timestamp column টা মুছে যাবে। dataset আপডেট হয়ে যাবে।
#
# **inplace=True না দিলে:**
# ```python
# dataset.drop("Timestamp", axis=1)
# ```
# এটা Timestamp ছাড়া একটা নতুন dataframe return করবে, কিন্তু original dataset একদম আগের মতোই থাকবে, কোনো পরিবর্তন হবে না।
#
# তাই না দিলে এভাবে লিখতে হতো —
# ```python
# dataset = dataset.drop("Timestamp", axis=1)
# ```
# মানে return হওয়া নতুন dataframe টাকে আবার dataset এ assign করতে হতো। inplace=True দিলে এই ঝামেলা নেই, pandas নিজেই সরাসরি dataset বদলে দেয়।

# %%
dataset
# Out:
#         What is your name?  What is your age? What is your gender?  \
# 0    Ayesha Siraji Shejuty                 21               Female
# 1          Nushrah Ipshita                 18               Female
# 2        Nabhan Ezaz Ilhan                 18                 Male
# 3     Rashedul Hoque Robin                 23                 Male
# 4          Mubashira Hoque                 22               Female
# ..                     ...                ...                  ...
# 406            Nila rahman                 19               Female
# 407          Abayat Rahman                 21                 Male
# 408            Talha Ahmed                 23                 Male
# 409         Latifur Rahman                 21                 Male
# 410              Dr.Biplob                 29                 Male
#
#     A child should sleep?  \
# 0              8 to 9 hrs
# 1              8 to 9 hrs
# 2              8 to 9 hrs
# 3              8 to 9 hrs
# 4             9 to 10 hrs
# ..                    ...
# 406            8 to 9 hrs
# 407            8 to 9 hrs
# 408            8 to 9 hrs
# 409            8 to 9 hrs
# 410            8 to 9 hrs
#
#     At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                          3 to 6 year
# 1                                          3 to 6 year
# 2                                          3 to 6 year
# 3                                          3 to 6 year
# 4                                          3 to 6 year
# ..                                                 ...
# 406                                        3 to 6 year
# 407                                        1 to 3 year
# 408                                        1 to 3 year
# 409                                        1 to 3 year
# 410                                        3 to 6 year
#
#     During the early growing stage of a child the cause of malnutrition according to you is-  \
# 0                                              Poverty
# 1                                              Poverty
# 2                           Lack of parental awareness
# 3                           Lack of parental awareness
# 4                                              Poverty
# ..                                                 ...
# 406                                            Poverty
# 407                                            Poverty
# 408                         Lack of parental awareness
# 409                         Lack of parental awareness
# 410                         Lack of parental awareness
#
#     Child nutrition can also effect by  \
# 0              Quantity of intake food
# 1                          Environment
# 2                          Family care
# 3                          Environment
# 4                          Family care
# ..                                 ...
# 406                Physical well-being
# 407                        Family care
# 408                        Environment
# 409                        Environment
# 410                        Environment
#
#     During puberty most of the child need to take proper amount of nutrients because  \
# 0                         They have started to growing
# 1                         They have started to growing
# 2            The growth rate is massive in this period
# 3                         They have started to growing
# 4                         They have started to growing
# ..                                                 ...
# 406                       They have started to growing
# 407                       They have started to growing
# 408                       They have started to growing
# 409                       They have started to growing
# 410                       They have started to growing
#
#     The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be  \
# 0                                         Malnutrition
# 1                                         Malnutrition
# 2    No if proper nutrients is getting by other foo...
# 3    No if proper nutrients is getting by other foo...
# 4                                         Malnutrition
# ..                                                 ...
# 406                                       Malnutrition
# 407  No if proper nutrients is getting by other foo...
# 408                                       Malnutrition
# 409  No if proper nutrients is getting by other foo...
# 410                                       Malnutrition
#
#     A girl child needs to have best care during puberty  \
# 0                             Due to her mental health
# 1                             Due to her mental health
# 2                      Attractions towards uncertainty
# 3                             Due to her mental health
# 4                                 Physiological change
# ..                                                 ...
# 406                           Due to her mental health
# 407                    Attractions towards uncertainty
# 408                           Due to her mental health
# 409                    Attractions towards uncertainty
# 410                    Attractions towards uncertainty
#
#     The most common malnutrition of children in our country  \
# 0                                              Rickets
# 1                                             Marasmus
# 2                                             Marasmus
# 3                                              Rickets
# 4                                              Rickets
# ..                                                 ...
# 406                                            Rickets
# 407                                            Rickets
# 408                                            Rickets
# 409                                        Kwashiorkor
# 410                                            Rickets
#
#     Do you prefer parental awareness in case of a sound health of a child  \
# 0                                       Strongly agree
# 1                                       Strongly agree
# 2                                       Strongly agree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 406                                     Strongly agree
# 407                                     Strongly agree
# 408                                     Strongly agree
# 409                                     Strongly agree
# 410                                     Strongly agree
#
#     Nutrition of a child related to  \
# 0             Quantity of nutrients
# 1             Quantity of nutrients
# 2      Including vegetables, fruits
# 3      Including vegetables, fruits
# 4             Quantity of nutrients
# ..                              ...
# 406           Quantity of nutrients
# 407           Quantity of nutrients
# 408           Quantity of nutrients
# 409            Milk as a supplement
# 410    Including vegetables, fruits
#
#     Diarrhea is a very common disease of infant. According to you it happens due to  \
# 0    Lack of cleanliness to the instruments that ar...
# 1                                Unhealthy environment
# 2    Lack of cleanliness to the instruments that ar...
# 3                                Unhealthy environment
# 4    Lack of cleanliness to the instruments that ar...
# ..                                                 ...
# 406                              Unhealthy environment
# 407  Lack of cleanliness to the instruments that ar...
# 408  Lack of cleanliness to the instruments that ar...
# 409  Lack of cleanliness to the instruments that ar...
# 410  Lack of cleanliness to the instruments that ar...
#
#     Some people think that feeding a child more and more Can increase their body growth. But according to you it is a  \
# 0                                Cause of malnutrition
# 1                                Cause of malnutrition
# 2                                Cause of malnutrition
# 3                                           Overweight
# 4                                           Overweight
# ..                                                 ...
# 406                              Cause of malnutrition
# 407                                         Overweight
# 408                              Cause of malnutrition
# 409                              Cause of malnutrition
# 410                              Cause of malnutrition
#
#     Whole grain foods such as breads, cereals that are high in Fibre  \
# 0                                         Making stool
# 1                                         Making stool
# 2                                         Making stool
# 3                                    Helps bone growth
# 4                                         Making stool
# ..                                                 ...
# 406                                  Helps bone growth
# 407                                  Helps bone growth
# 408                                       Making stool
# 409                                       Making stool
# 410                                  Helps bone growth
#
#     Toddlers & preschoolers should have following nutrients in their diet
# 0    Milk for the growth but sometimes it causes mi...
# 1    Milk for the growth but sometimes it causes mi...
# 2    Milk for the growth but sometimes it causes mi...
# 3                              Calcium for bone growth
# 4                              Calcium for bone growth
# ..                                                 ...
# 406                            Calcium for bone growth
# 407                            Calcium for bone growth
# 408                            Calcium for bone growth
# 409                            Calcium for bone growth
# 410                            Calcium for bone growth
#
# [411 rows x 17 columns]

# %%
dataset.drop("What is your name?", axis=1, inplace=True)

dataset
# Out:
#      What is your age? What is your gender? A child should sleep?  \
# 0                   21               Female            8 to 9 hrs
# 1                   18               Female            8 to 9 hrs
# 2                   18                 Male            8 to 9 hrs
# 3                   23                 Male            8 to 9 hrs
# 4                   22               Female           9 to 10 hrs
# ..                 ...                  ...                   ...
# 406                 19               Female            8 to 9 hrs
# 407                 21                 Male            8 to 9 hrs
# 408                 23                 Male            8 to 9 hrs
# 409                 21                 Male            8 to 9 hrs
# 410                 29                 Male            8 to 9 hrs
#
#     At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                          3 to 6 year
# 1                                          3 to 6 year
# 2                                          3 to 6 year
# 3                                          3 to 6 year
# 4                                          3 to 6 year
# ..                                                 ...
# 406                                        3 to 6 year
# 407                                        1 to 3 year
# 408                                        1 to 3 year
# 409                                        1 to 3 year
# 410                                        3 to 6 year
#
#     During the early growing stage of a child the cause of malnutrition according to you is-  \
# 0                                              Poverty
# 1                                              Poverty
# 2                           Lack of parental awareness
# 3                           Lack of parental awareness
# 4                                              Poverty
# ..                                                 ...
# 406                                            Poverty
# 407                                            Poverty
# 408                         Lack of parental awareness
# 409                         Lack of parental awareness
# 410                         Lack of parental awareness
#
#     Child nutrition can also effect by  \
# 0              Quantity of intake food
# 1                          Environment
# 2                          Family care
# 3                          Environment
# 4                          Family care
# ..                                 ...
# 406                Physical well-being
# 407                        Family care
# 408                        Environment
# 409                        Environment
# 410                        Environment
#
#     During puberty most of the child need to take proper amount of nutrients because  \
# 0                         They have started to growing
# 1                         They have started to growing
# 2            The growth rate is massive in this period
# 3                         They have started to growing
# 4                         They have started to growing
# ..                                                 ...
# 406                       They have started to growing
# 407                       They have started to growing
# 408                       They have started to growing
# 409                       They have started to growing
# 410                       They have started to growing
#
#     The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be  \
# 0                                         Malnutrition
# 1                                         Malnutrition
# 2    No if proper nutrients is getting by other foo...
# 3    No if proper nutrients is getting by other foo...
# 4                                         Malnutrition
# ..                                                 ...
# 406                                       Malnutrition
# 407  No if proper nutrients is getting by other foo...
# 408                                       Malnutrition
# 409  No if proper nutrients is getting by other foo...
# 410                                       Malnutrition
#
#     A girl child needs to have best care during puberty  \
# 0                             Due to her mental health
# 1                             Due to her mental health
# 2                      Attractions towards uncertainty
# 3                             Due to her mental health
# 4                                 Physiological change
# ..                                                 ...
# 406                           Due to her mental health
# 407                    Attractions towards uncertainty
# 408                           Due to her mental health
# 409                    Attractions towards uncertainty
# 410                    Attractions towards uncertainty
#
#     The most common malnutrition of children in our country  \
# 0                                              Rickets
# 1                                             Marasmus
# 2                                             Marasmus
# 3                                              Rickets
# 4                                              Rickets
# ..                                                 ...
# 406                                            Rickets
# 407                                            Rickets
# 408                                            Rickets
# 409                                        Kwashiorkor
# 410                                            Rickets
#
#     Do you prefer parental awareness in case of a sound health of a child  \
# 0                                       Strongly agree
# 1                                       Strongly agree
# 2                                       Strongly agree
# 3                                                Agree
# 4                                                Agree
# ..                                                 ...
# 406                                     Strongly agree
# 407                                     Strongly agree
# 408                                     Strongly agree
# 409                                     Strongly agree
# 410                                     Strongly agree
#
#     Nutrition of a child related to  \
# 0             Quantity of nutrients
# 1             Quantity of nutrients
# 2      Including vegetables, fruits
# 3      Including vegetables, fruits
# 4             Quantity of nutrients
# ..                              ...
# 406           Quantity of nutrients
# 407           Quantity of nutrients
# 408           Quantity of nutrients
# 409            Milk as a supplement
# 410    Including vegetables, fruits
#
#     Diarrhea is a very common disease of infant. According to you it happens due to  \
# 0    Lack of cleanliness to the instruments that ar...
# 1                                Unhealthy environment
# 2    Lack of cleanliness to the instruments that ar...
# 3                                Unhealthy environment
# 4    Lack of cleanliness to the instruments that ar...
# ..                                                 ...
# 406                              Unhealthy environment
# 407  Lack of cleanliness to the instruments that ar...
# 408  Lack of cleanliness to the instruments that ar...
# 409  Lack of cleanliness to the instruments that ar...
# 410  Lack of cleanliness to the instruments that ar...
#
#     Some people think that feeding a child more and more Can increase their body growth. But according to you it is a  \
# 0                                Cause of malnutrition
# 1                                Cause of malnutrition
# 2                                Cause of malnutrition
# 3                                           Overweight
# 4                                           Overweight
# ..                                                 ...
# 406                              Cause of malnutrition
# 407                                         Overweight
# 408                              Cause of malnutrition
# 409                              Cause of malnutrition
# 410                              Cause of malnutrition
#
#     Whole grain foods such as breads, cereals that are high in Fibre  \
# 0                                         Making stool
# 1                                         Making stool
# 2                                         Making stool
# 3                                    Helps bone growth
# 4                                         Making stool
# ..                                                 ...
# 406                                  Helps bone growth
# 407                                  Helps bone growth
# 408                                       Making stool
# 409                                       Making stool
# 410                                  Helps bone growth
#
#     Toddlers & preschoolers should have following nutrients in their diet
# 0    Milk for the growth but sometimes it causes mi...
# 1    Milk for the growth but sometimes it causes mi...
# 2    Milk for the growth but sometimes it causes mi...
# 3                              Calcium for bone growth
# 4                              Calcium for bone growth
# ..                                                 ...
# 406                            Calcium for bone growth
# 407                            Calcium for bone growth
# 408                            Calcium for bone growth
# 409                            Calcium for bone growth
# 410                            Calcium for bone growth
#
# [411 rows x 16 columns]

# %% [markdown]
# # **Doing Label Encoding**
#
# ---

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %% [markdown]
# **Gender column**

# %%
dataset["What is your gender?"]=le.fit_transform(dataset["What is your gender?"])

# %%
dataset["What is your gender?"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 406    0
# 407    1
# 408    1
# 409    1
# 410    1
# Name: What is your gender?, Length: 411, dtype: int64

# %% [markdown]
# **A child should sleep?**

# %%
dataset["A child should sleep?"] = le.fit_transform(dataset["A child should sleep?"])

# %%
dataset["A child should sleep?"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 406    1
# 407    1
# 408    1
# 409    1
# 410    1
# Name: A child should sleep?, Length: 411, dtype: int64

# %% [markdown]
# **At what ages do food allergies, iron deficiency and occur in children?**

# %%
dataset["At what ages do food allergies, iron deficiency and occur in children?"] = le.fit_transform(dataset["At what ages do food allergies, iron deficiency and occur in children?"])
dataset["At what ages do food allergies, iron deficiency and occur in children?"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 406    1
# 407    0
# 408    0
# 409    0
# 410    1
# Name: At what ages do food allergies, iron deficiency and occur in children?, Length: 411, dtype: int64

# %% [markdown]
# **During the early growing stage of a child the cause of malnutrition according to you is-**

# %%
dataset["During the early growing stage of a child the cause of malnutrition according to you is-"] = le.fit_transform(dataset["During the early growing stage of a child the cause of malnutrition according to you is-"])
dataset["During the early growing stage of a child the cause of malnutrition according to you is-"]
# Out:
# 0      2
# 1      2
# 2      0
# 3      0
# 4      2
#       ..
# 406    2
# 407    2
# 408    0
# 409    0
# 410    0
# Name: During the early growing stage of a child the cause of malnutrition according to you is-, Length: 411, dtype: int64

# %% [markdown]
# Eita dependent tai **Child nutrition can also effect by** ke label encoding korbo na

# %% [markdown]
# **During puberty most of the child need to take proper amount of nutrients because**

# %%
dataset["During puberty most of the child need to take proper amount of nutrients because"] = le.fit_transform(dataset["During puberty most of the child need to take proper amount of nutrients because"])
dataset["During puberty most of the child need to take proper amount of nutrients because"]
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 406    2
# 407    2
# 408    2
# 409    2
# 410    2
# Name: During puberty most of the child need to take proper amount of nutrients because, Length: 411, dtype: int64

# %% [markdown]
# **The most important nutrition source of an infant or baby is breast feeding...**

# %%
dataset["The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be"] = le.fit_transform(dataset["The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be"])
dataset["The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be"]
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 406    0
# 407    1
# 408    0
# 409    1
# 410    0
# Name: The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be, Length: 411, dtype: int64

# %% [markdown]
# **A girl child needs to have best care during puberty**

# %%
dataset["A girl child needs to have best care during puberty"] = le.fit_transform(dataset["A girl child needs to have best care during puberty"])
dataset["A girl child needs to have best care during puberty"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      2
#       ..
# 406    1
# 407    0
# 408    1
# 409    0
# 410    0
# Name: A girl child needs to have best care during puberty, Length: 411, dtype: int64

# %% [markdown]
# **The most common malnutrition of children in our country**

# %%
dataset["The most common malnutrition of children in our country"] = le.fit_transform(dataset["The most common malnutrition of children in our country"])
dataset["The most common malnutrition of children in our country"]
# Out:
# 0      2
# 1      1
# 2      1
# 3      2
# 4      2
#       ..
# 406    2
# 407    2
# 408    2
# 409    0
# 410    2
# Name: The most common malnutrition of children in our country, Length: 411, dtype: int64

# %% [markdown]
# **Do you prefer parental awareness in case of a sound health of a child**

# %%
dataset["Do you prefer parental awareness in case of a sound health of a child"] = le.fit_transform(dataset["Do you prefer parental awareness in case of a sound health of a child"])
dataset["Do you prefer parental awareness in case of a sound health of a child"]
# Out:
# 0      2
# 1      2
# 2      2
# 3      0
# 4      0
#       ..
# 406    2
# 407    2
# 408    2
# 409    2
# 410    2
# Name: Do you prefer parental awareness in case of a sound health of a child, Length: 411, dtype: int64

# %% [markdown]
# **Do you prefer parental awareness in case of a sound health of a child**

# %%
dataset["Nutrition of a child related to"] = le.fit_transform(dataset["Nutrition of a child related to"])
dataset["Nutrition of a child related to"]
# Out:
# 0      2
# 1      2
# 2      0
# 3      0
# 4      2
#       ..
# 406    2
# 407    2
# 408    2
# 409    1
# 410    0
# Name: Nutrition of a child related to, Length: 411, dtype: int64

# %% [markdown]
# **Diarrhea is a very common disease of infant. According to you it happens due to**

# %%
dataset["Diarrhea is a very common disease of infant. According to you it happens due to"] = le.fit_transform(dataset["Diarrhea is a very common disease of infant. According to you it happens due to"])
dataset["Diarrhea is a very common disease of infant. According to you it happens due to"]
# Out:
# 0      0
# 1      2
# 2      0
# 3      2
# 4      0
#       ..
# 406    2
# 407    0
# 408    0
# 409    0
# 410    0
# Name: Diarrhea is a very common disease of infant. According to you it happens due to, Length: 411, dtype: int64

# %% [markdown]
# **Some people think that feeding a child more and more Can increase their body growth. But according to you it is a**

# %%
dataset["Some people think that feeding a child more and more Can increase their body growth. But according to you it is a"] = le.fit_transform(dataset["Some people think that feeding a child more and more Can increase their body growth. But according to you it is a"])
dataset["Some people think that feeding a child more and more Can increase their body growth. But according to you it is a"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      2
# 4      2
#       ..
# 406    0
# 407    2
# 408    0
# 409    0
# 410    0
# Name: Some people think that feeding a child more and more Can increase their body growth. But according to you it is a, Length: 411, dtype: int64

# %% [markdown]
# **Whole grain foods such as breads, cereals that are high in Fibre**

# %%
dataset["Whole grain foods such as breads, cereals that are high in Fibre"] = le.fit_transform(dataset["Whole grain foods such as breads, cereals that are high in Fibre"])
dataset["Whole grain foods such as breads, cereals that are high in Fibre"]
# Out:
# 0      3
# 1      3
# 2      3
# 3      0
# 4      3
#       ..
# 406    0
# 407    0
# 408    3
# 409    3
# 410    0
# Name: Whole grain foods such as breads, cereals that are high in Fibre, Length: 411, dtype: int64

# %% [markdown]
# **Toddlers & preschoolers should have following nutrients in their diet**

# %%
dataset["Toddlers & preschoolers should have following nutrients in their diet"] = le.fit_transform(dataset["Toddlers & preschoolers should have following nutrients in their diet"])
dataset["Toddlers & preschoolers should have following nutrients in their diet"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 406    0
# 407    0
# 408    0
# 409    0
# 410    0
# Name: Toddlers & preschoolers should have following nutrients in their diet, Length: 411, dtype: int64

# %%
dataset.head(20)
# Out:
#     What is your age?  What is your gender?  A child should sleep?  \
# 0                  21                     0                      1
# 1                  18                     0                      1
# 2                  18                     1                      1
# 3                  23                     1                      1
# 4                  22                     0                      2
# 5                  23                     1                      2
# 6                  24                     1                      1
# 7                  20                     0                      1
# 8                  24                     1                      2
# 9                  22                     0                      1
# 10                 23                     1                      2
# 11                 23                     1                      1
# 12                 21                     1                      1
# 13                 18                     0                      1
# 14                 18                     0                      2
# 15                 18                     0                      1
# 16                 17                     0                      1
# 17                 18                     0                      1
# 18                 17                     0                      1
# 19                 22                     1                      0
#
#     At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   1
# 4                                                   1
# 5                                                   2
# 6                                                   0
# 7                                                   2
# 8                                                   1
# 9                                                   2
# 10                                                  1
# 11                                                  1
# 12                                                  0
# 13                                                  0
# 14                                                  1
# 15                                                  2
# 16                                                  2
# 17                                                  0
# 18                                                  0
# 19                                                  1
#
#     During the early growing stage of a child the cause of malnutrition according to you is-  \
# 0                                                   2
# 1                                                   2
# 2                                                   0
# 3                                                   0
# 4                                                   2
# 5                                                   0
# 6                                                   0
# 7                                                   0
# 8                                                   2
# 9                                                   2
# 10                                                  2
# 11                                                  0
# 12                                                  2
# 13                                                  2
# 14                                                  2
# 15                                                  0
# 16                                                  2
# 17                                                  0
# 18                                                  0
# 19                                                  0
#
#    Child nutrition can also effect by  \
# 0             Quantity of intake food
# 1                         Environment
# 2                         Family care
# 3                         Environment
# 4                         Family care
# 5                         Family care
# 6                         Environment
# 7                 Physical well-being
# 8                         Family care
# 9                         Environment
# 10                        Family care
# 11            Quantity of intake food
# 12                        Family care
# 13            Quantity of intake food
# 14            Quantity of intake food
# 15                        Family care
# 16            Quantity of intake food
# 17            Quantity of intake food
# 18                        Family care
# 19                        Family care
#
#     During puberty most of the child need to take proper amount of nutrients because  \
# 0                                                   2
# 1                                                   2
# 2                                                   1
# 3                                                   2
# 4                                                   2
# 5                                                   2
# 6                                                   1
# 7                                                   0
# 8                                                   2
# 9                                                   1
# 10                                                  1
# 11                                                  0
# 12                                                  0
# 13                                                  0
# 14                                                  1
# 15                                                  1
# 16                                                  1
# 17                                                  0
# 18                                                  1
# 19                                                  0
#
#     The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be  \
# 0                                                   0
# 1                                                   0
# 2                                                   1
# 3                                                   1
# 4                                                   0
# 5                                                   2
# 6                                                   0
# 7                                                   0
# 8                                                   2
# 9                                                   0
# 10                                                  0
# 11                                                  1
# 12                                                  2
# 13                                                  2
# 14                                                  2
# 15                                                  0
# 16                                                  0
# 17                                                  0
# 18                                                  2
# 19                                                  2
#
#     A girl child needs to have best care during puberty  \
# 0                                                   1
# 1                                                   1
# 2                                                   0
# 3                                                   1
# 4                                                   2
# 5                                                   2
# 6                                                   0
# 7                                                   2
# 8                                                   2
# 9                                                   0
# 10                                                  0
# 11                                                  2
# 12                                                  1
# 13                                                  2
# 14                                                  0
# 15                                                  2
# 16                                                  1
# 17                                                  1
# 18                                                  1
# 19                                                  2
#
#     The most common malnutrition of children in our country  \
# 0                                                   2
# 1                                                   1
# 2                                                   1
# 3                                                   2
# 4                                                   2
# 5                                                   2
# 6                                                   2
# 7                                                   2
# 8                                                   0
# 9                                                   2
# 10                                                  1
# 11                                                  2
# 12                                                  0
# 13                                                  2
# 14                                                  2
# 15                                                  1
# 16                                                  2
# 17                                                  0
# 18                                                  1
# 19                                                  0
#
#     Do you prefer parental awareness in case of a sound health of a child  \
# 0                                                   2
# 1                                                   2
# 2                                                   2
# 3                                                   0
# 4                                                   0
# 5                                                   2
# 6                                                   0
# 7                                                   0
# 8                                                   0
# 9                                                   0
# 10                                                  0
# 11                                                  0
# 12                                                  2
# 13                                                  2
# 14                                                  2
# 15                                                  0
# 16                                                  2
# 17                                                  0
# 18                                                  0
# 19                                                  2
#
#     Nutrition of a child related to  \
# 0                                 2
# 1                                 2
# 2                                 0
# 3                                 0
# 4                                 2
# 5                                 0
# 6                                 2
# 7                                 2
# 8                                 2
# 9                                 2
# 10                                2
# 11                                1
# 12                                1
# 13                                2
# 14                                2
# 15                                0
# 16                                0
# 17                                0
# 18                                0
# 19                                2
#
#     Diarrhea is a very common disease of infant. According to you it happens due to  \
# 0                                                   0
# 1                                                   2
# 2                                                   0
# 3                                                   2
# 4                                                   0
# 5                                                   1
# 6                                                   0
# 7                                                   0
# 8                                                   2
# 9                                                   2
# 10                                                  0
# 11                                                  0
# 12                                                  2
# 13                                                  0
# 14                                                  2
# 15                                                  1
# 16                                                  0
# 17                                                  1
# 18                                                  2
# 19                                                  0
#
#     Some people think that feeding a child more and more Can increase their body growth. But according to you it is a  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   2
# 4                                                   2
# 5                                                   2
# 6                                                   0
# 7                                                   1
# 8                                                   2
# 9                                                   1
# 10                                                  2
# 11                                                  2
# 12                                                  2
# 13                                                  2
# 14                                                  1
# 15                                                  0
# 16                                                  1
# 17                                                  1
# 18                                                  0
# 19                                                  1
#
#     Whole grain foods such as breads, cereals that are high in Fibre  \
# 0                                                   3
# 1                                                   3
# 2                                                   3
# 3                                                   0
# 4                                                   3
# 5                                                   2
# 6                                                   0
# 7                                                   3
# 8                                                   0
# 9                                                   2
# 10                                                  2
# 11                                                  2
# 12                                                  1
# 13                                                  2
# 14                                                  1
# 15                                                  0
# 16                                                  0
# 17                                                  2
# 18                                                  3
# 19                                                  2
#
#     Toddlers & preschoolers should have following nutrients in their diet
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   0
# 4                                                   0
# 5                                                   0
# 6                                                   0
# 7                                                   0
# 8                                                   2
# 9                                                   2
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  0
# 14                                                  0
# 15                                                  0
# 16                                                  0
# 17                                                  2
# 18                                                  0
# 19                                                  0

# %% [markdown]
# # Class 06

# %%
dataset.columns[5]
# Out:
# 'Child nutrition can also effect by'

# %%
x=dataset.drop(dataset.columns[5], axis=1)
x
# Out:
#      What is your age?  What is your gender?  A child should sleep?  \
# 0                   21                     0                      1
# 1                   18                     0                      1
# 2                   18                     1                      1
# 3                   23                     1                      1
# 4                   22                     0                      2
# ..                 ...                   ...                    ...
# 406                 19                     0                      1
# 407                 21                     1                      1
# 408                 23                     1                      1
# 409                 21                     1                      1
# 410                 29                     1                      1
#
#      At what ages do food allergies, iron deficiency and occur in children?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 406                                                  1
# 407                                                  0
# 408                                                  0
# 409                                                  0
# 410                                                  1
#
#      During the early growing stage of a child the cause of malnutrition according to you is-  \
# 0                                                    2
# 1                                                    2
# 2                                                    0
# 3                                                    0
# 4                                                    2
# ..                                                 ...
# 406                                                  2
# 407                                                  2
# 408                                                  0
# 409                                                  0
# 410                                                  0
#
#      During puberty most of the child need to take proper amount of nutrients because  \
# 0                                                    2
# 1                                                    2
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 406                                                  2
# 407                                                  2
# 408                                                  2
# 409                                                  2
# 410                                                  2
#
#      The most important nutrition source of  an infant or baby is breast feeding. Without breast feeding they can be grownup but do you think it can be  \
# 0                                                    0
# 1                                                    0
# 2                                                    1
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 406                                                  0
# 407                                                  1
# 408                                                  0
# 409                                                  1
# 410                                                  0
#
#      A girl child needs to have best care during puberty  \
# 0                                                    1
# 1                                                    1
# 2                                                    0
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 406                                                  1
# 407                                                  0
# 408                                                  1
# 409                                                  0
# 410                                                  0
#
#      The most common malnutrition of children in our country  \
# 0                                                    2
# 1                                                    1
# 2                                                    1
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 406                                                  2
# 407                                                  2
# 408                                                  2
# 409                                                  0
# 410                                                  2
#
#      Do you prefer parental awareness in case of a sound health of a child  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 406                                                  2
# 407                                                  2
# 408                                                  2
# 409                                                  2
# 410                                                  2
#
#      Nutrition of a child related to  \
# 0                                  2
# 1                                  2
# 2                                  0
# 3                                  0
# 4                                  2
# ..                               ...
# 406                                2
# 407                                2
# 408                                2
# 409                                1
# 410                                0
#
#      Diarrhea is a very common disease of infant. According to you it happens due to  \
# 0                                                    0
# 1                                                    2
# 2                                                    0
# 3                                                    2
# 4                                                    0
# ..                                                 ...
# 406                                                  2
# 407                                                  0
# 408                                                  0
# 409                                                  0
# 410                                                  0
#
#      Some people think that feeding a child more and more Can increase their body growth. But according to you it is a  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 406                                                  0
# 407                                                  2
# 408                                                  0
# 409                                                  0
# 410                                                  0
#
#      Whole grain foods such as breads, cereals that are high in Fibre  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 406                                                  0
# 407                                                  0
# 408                                                  3
# 409                                                  3
# 410                                                  0
#
#      Toddlers & preschoolers should have following nutrients in their diet
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 406                                                  0
# 407                                                  0
# 408                                                  0
# 409                                                  0
# 410                                                  0
#
# [411 rows x 15 columns]

# %%
y=dataset["Child nutrition can also effect by"]
y
# Out:
# 0      Quantity of intake food
# 1                  Environment
# 2                  Family care
# 3                  Environment
# 4                  Family care
#                 ...
# 406        Physical well-being
# 407                Family care
# 408                Environment
# 409                Environment
# 410                Environment
# Name: Child nutrition can also effect by, Length: 411, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=0)

# %% [markdown]
# # Supervised Algorithms

# %% [markdown]
# ## **1. Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print(accuracy_score(y_test, ypred))
print(classification_report(y_test, ypred))
print(confusion_matrix(y_test, ypred))
# Out:
# 0.40963855421686746
#                          precision    recall  f1-score   support
#
#             Environment       0.55      0.57      0.56        37
#             Family care       0.50      0.30      0.38        33
#     Physical well-being       0.16      0.33      0.21         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.41        83
#               macro avg       0.30      0.30      0.29        83
#            weighted avg       0.46      0.41      0.42        83
#
# [[21  6  7  3]
#  [15 10  6  2]
#  [ 2  3  3  1]
#  [ 0  1  3  0]]

# %% [markdown]
# ## **2. KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
kc=KNeighborsClassifier()
kc.fit(x_train, y_train)
ypredk=kc.predict(x_test)
print(accuracy_score(y_test, ypredk))
print(classification_report(y_test, ypredk))
print(confusion_matrix(y_test, ypredk))
# Out:
# 0.46987951807228917
#                          precision    recall  f1-score   support
#
#             Environment       0.52      0.81      0.63        37
#             Family care       0.43      0.27      0.33        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.47        83
#               macro avg       0.24      0.27      0.24        83
#            weighted avg       0.40      0.47      0.41        83
#
# [[30  7  0  0]
#  [21  9  2  1]
#  [ 5  3  0  1]
#  [ 2  2  0  0]]

# %% [markdown]
# ## **3. Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train, y_train)
ypredr=rf.predict(x_test)
print(accuracy_score(y_test, ypredr))
print(classification_report(y_test, ypredr))
print(confusion_matrix(y_test, ypredr))
# Out:
# 0.5301204819277109
#                          precision    recall  f1-score   support
#
#             Environment       0.54      0.78      0.64        37
#             Family care       0.62      0.45      0.53        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.53        83
#               macro avg       0.29      0.31      0.29        83
#            weighted avg       0.49      0.53      0.49        83
#
# [[29  6  2  0]
#  [15 15  3  0]
#  [ 6  3  0  0]
#  [ 4  0  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# Accuracy jeita beshi sei model/algorithm ta nibo . erpr erokom aro lazy model algorithm apply apply korbe supervised and unsupervised algorithm

# %% [markdown]
# ## **4. Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

lr = LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)
ypred_lr = lr.predict(x_test)
print("Logistic Regression")
print("Accuracy:", accuracy_score(y_test, ypred_lr))
print(classification_report(y_test, ypred_lr))
print(confusion_matrix(y_test, ypred_lr))
# Out:
# Logistic Regression
# Accuracy: 0.4819277108433735
#                          precision    recall  f1-score   support
#
#             Environment       0.54      0.76      0.63        37
#             Family care       0.67      0.36      0.47        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.48        83
#               macro avg       0.30      0.28      0.27        83
#            weighted avg       0.51      0.48      0.47        83
#
# [[28  4  3  2]
#  [15 12  3  3]
#  [ 6  2  0  1]
#  [ 3  0  1  0]]

# %% [markdown]
# ## **5. Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

svm = SVC()
svm.fit(x_train, y_train)
ypred_svm = svm.predict(x_test)
print("Support Vector Machine (SVM)")
print("Accuracy:", accuracy_score(y_test, ypred_svm))
print(classification_report(y_test, ypred_svm))
print(confusion_matrix(y_test, ypred_svm))
# Out:
# Support Vector Machine (SVM)
# Accuracy: 0.4457831325301205
#                          precision    recall  f1-score   support
#
#             Environment       0.45      1.00      0.62        37
#             Family care       0.00      0.00      0.00        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.45        83
#               macro avg       0.11      0.25      0.15        83
#            weighted avg       0.20      0.45      0.27        83
#
# [[37  0  0  0]
#  [33  0  0  0]
#  [ 9  0  0  0]
#  [ 4  0  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## **6. Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

nb = GaussianNB()
nb.fit(x_train, y_train)
ypred_nb = nb.predict(x_test)
print("Naive Bayes")
print("Accuracy:", accuracy_score(y_test, ypred_nb))
print(classification_report(y_test, ypred_nb))
print(confusion_matrix(y_test, ypred_nb))
# Out:
# Naive Bayes
# Accuracy: 0.4578313253012048
#                          precision    recall  f1-score   support
#
#             Environment       0.53      0.68      0.60        37
#             Family care       0.65      0.33      0.44        33
#     Physical well-being       0.08      0.11      0.09         9
# Quantity of intake food       0.17      0.25      0.20         4
#
#                accuracy                           0.46        83
#               macro avg       0.36      0.34      0.33        83
#            weighted avg       0.51      0.46      0.46        83
#
# [[25  4  6  2]
#  [16 11  4  2]
#  [ 5  2  1  1]
#  [ 1  0  2  1]]

# %% [markdown]
# ## **7. Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

gb = GradientBoostingClassifier()
gb.fit(x_train, y_train)
ypred_gb = gb.predict(x_test)
print("Gradient Boosting")
print("Accuracy:", accuracy_score(y_test, ypred_gb))
print(classification_report(y_test, ypred_gb))
print(confusion_matrix(y_test, ypred_gb))
# Out:
# Gradient Boosting
# Accuracy: 0.5421686746987951
#                          precision    recall  f1-score   support
#
#             Environment       0.56      0.73      0.64        37
#             Family care       0.68      0.45      0.55        33
#     Physical well-being       0.12      0.11      0.12         9
# Quantity of intake food       0.40      0.50      0.44         4
#
#                accuracy                           0.54        83
#               macro avg       0.44      0.45      0.44        83
#            weighted avg       0.55      0.54      0.53        83
#
# [[27  5  4  1]
#  [13 15  3  2]
#  [ 6  2  1  0]
#  [ 2  0  0  2]]

# %% [markdown]
# ## **8. AdaBoost**

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

ada = AdaBoostClassifier()
ada.fit(x_train, y_train)
ypred_ada = ada.predict(x_test)
print("AdaBoost")
print("Accuracy:", accuracy_score(y_test, ypred_ada))
print(classification_report(y_test, ypred_ada))
print(confusion_matrix(y_test, ypred_ada))
# Out:
# AdaBoost
# Accuracy: 0.39759036144578314
#                          precision    recall  f1-score   support
#
#             Environment       0.48      0.68      0.56        37
#             Family care       0.36      0.24      0.29        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.40        83
#               macro avg       0.21      0.23      0.21        83
#            weighted avg       0.36      0.40      0.37        83
#
# [[25 10  2  0]
#  [20  8  4  1]
#  [ 6  3  0  0]
#  [ 1  1  2  0]]

# %% [markdown]
# ## **9. Extra Trees**

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

et = ExtraTreesClassifier()
et.fit(x_train, y_train)
ypred_et = et.predict(x_test)
print("Extra Trees")
print("Accuracy:", accuracy_score(y_test, ypred_et))
print(classification_report(y_test, ypred_et))
print(confusion_matrix(y_test, ypred_et))
# Out:
# Extra Trees
# Accuracy: 0.4939759036144578
#                          precision    recall  f1-score   support
#
#             Environment       0.53      0.73      0.61        37
#             Family care       0.54      0.42      0.47        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.49        83
#               macro avg       0.27      0.29      0.27        83
#            weighted avg       0.45      0.49      0.46        83
#
# [[27  8  2  0]
#  [16 14  3  0]
#  [ 5  3  0  1]
#  [ 3  1  0  0]]

# %% [markdown]
# ## **10. Bagging Classifier**

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

bag = BaggingClassifier()
bag.fit(x_train, y_train)
ypred_bag = bag.predict(x_test)
print("Bagging Classifier")
print("Accuracy:", accuracy_score(y_test, ypred_bag))
print(classification_report(y_test, ypred_bag))
print(confusion_matrix(y_test, ypred_bag))
# Out:
# Bagging Classifier
# Accuracy: 0.5301204819277109
#                          precision    recall  f1-score   support
#
#             Environment       0.67      0.70      0.68        37
#             Family care       0.62      0.48      0.54        33
#     Physical well-being       0.15      0.22      0.18         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.53        83
#               macro avg       0.36      0.35      0.35        83
#            weighted avg       0.56      0.53      0.54        83
#
# [[26  6  3  2]
#  [ 8 16  7  2]
#  [ 3  3  2  1]
#  [ 2  1  1  0]]

# %% [markdown]
# ## **11. Linear Discriminant Analysis (LDA)**

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

lda = LinearDiscriminantAnalysis()
lda.fit(x_train, y_train)
ypred_lda = lda.predict(x_test)
print("Linear Discriminant Analysis (LDA)")
print("Accuracy:", accuracy_score(y_test, ypred_lda))
print(classification_report(y_test, ypred_lda))
print(confusion_matrix(y_test, ypred_lda))
# Out:
# Linear Discriminant Analysis (LDA)
# Accuracy: 0.5301204819277109
#                          precision    recall  f1-score   support
#
#             Environment       0.55      0.76      0.64        37
#             Family care       0.74      0.42      0.54        33
#     Physical well-being       0.20      0.22      0.21         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.53        83
#               macro avg       0.37      0.35      0.35        83
#            weighted avg       0.56      0.53      0.52        83
#
# [[28  4  4  1]
#  [15 14  3  1]
#  [ 5  1  2  1]
#  [ 3  0  1  0]]

# %% [markdown]
# ## **12. Ridge Classifier**

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

ridge = RidgeClassifier()
ridge.fit(x_train, y_train)
ypred_ridge = ridge.predict(x_test)
print("Ridge Classifier")
print("Accuracy:", accuracy_score(y_test, ypred_ridge))
print(classification_report(y_test, ypred_ridge))
print(confusion_matrix(y_test, ypred_ridge))
# Out:
# Ridge Classifier
# Accuracy: 0.5421686746987951
#                          precision    recall  f1-score   support
#
#             Environment       0.55      0.78      0.64        37
#             Family care       0.65      0.45      0.54        33
#     Physical well-being       0.14      0.11      0.12         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.54        83
#               macro avg       0.34      0.34      0.33        83
#            weighted avg       0.52      0.54      0.51        83
#
# [[29  5  3  0]
#  [16 15  2  0]
#  [ 5  3  1  0]
#  [ 3  0  1  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## **13. SGD Classifier**

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
ypred_sgd = sgd.predict(x_test)
print("SGD Classifier")
print("Accuracy:", accuracy_score(y_test, ypred_sgd))
print(classification_report(y_test, ypred_sgd))
print(confusion_matrix(y_test, ypred_sgd))
# Out:
# SGD Classifier
# Accuracy: 0.42168674698795183
#                          precision    recall  f1-score   support
#
#             Environment       0.45      0.95      0.61        37
#             Family care       0.00      0.00      0.00        33
#     Physical well-being       0.00      0.00      0.00         9
# Quantity of intake food       0.00      0.00      0.00         4
#
#                accuracy                           0.42        83
#               macro avg       0.11      0.24      0.15        83
#            weighted avg       0.20      0.42      0.27        83
#
# [[35  0  2  0]
#  [32  0  1  0]
#  [ 8  0  0  1]
#  [ 3  0  1  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## **All Model Accuracy Comparison**

# %%
results = {
    "Decision Tree": accuracy_score(y_test, ypred),
    "KNN": accuracy_score(y_test, ypredk),
    "Random Forest": accuracy_score(y_test, ypredr),
    "Logistic Regression": accuracy_score(y_test, ypred_lr),
    "SVM": accuracy_score(y_test, ypred_svm),
    "Naive Bayes": accuracy_score(y_test, ypred_nb),
    "Gradient Boosting": accuracy_score(y_test, ypred_gb),
    "AdaBoost": accuracy_score(y_test, ypred_ada),
    "Extra Trees": accuracy_score(y_test, ypred_et),
    "Bagging": accuracy_score(y_test, ypred_bag),
    "LDA": accuracy_score(y_test, ypred_lda),
    "Ridge Classifier": accuracy_score(y_test, ypred_ridge),
    "SGD Classifier": accuracy_score(y_test, ypred_sgd),
}

for model, acc in sorted(results.items(), key=lambda x: x[1], reverse=True):
    print(f"{model}: {acc:.4f}")
# Out:
# Gradient Boosting: 0.5422
# Ridge Classifier: 0.5422
# Random Forest: 0.5301
# Bagging: 0.5301
# LDA: 0.5301
# Extra Trees: 0.4940
# Logistic Regression: 0.4819
# KNN: 0.4699
# Naive Bayes: 0.4578
# SVM: 0.4458
# SGD Classifier: 0.4217
# Decision Tree: 0.4096
# AdaBoost: 0.3976
